# %% [markdown]
# <p style = "font-size : 20px; color : #532e1c ; font-family : 'Comic Sans MS'; text-align : center; background-color : #bedcfa; border-radius: 5px 5px;"><strong>MASTERING INSURANCE FRAUD: The Ensemble Learning Strategy that Redefines Detection!</strong></p>

# %% [markdown]
# <div style="background-color:#E6F9E6; border:2px solid #66C2A5; padding:20px; border-radius:10px; box-shadow: 0 2px 4px 0 rgba(0,0,0,0.1); font-family:Georgia, serif;">
#   <h1 style="color:#4A90E2; text-shadow: 1px 1px #FFF; text-align:center;">Aim & Objectives</h1>
#   <h2 style="color:#66C2A5; text-align:left; font-size:20px;">Aim</h2>
#   <p style="color:#333; font-size:16px;">
# To develop a robust ensemble learning model for effective <strong style="color:#FF5733;">insurance fraud detection</strong>, addressing a critical <strong style="color:#FFC300;">business challenge</strong>.
#   </p>
#
#   <h2 style="color:#66C2A5; text-align:left; font-size:20px;">Objectives</h2>
#   <ul style="color:#333; font-size:16px;">
#     <li><strong style="color:#FF5733;">Identify fraudulent patterns</strong> using multiple machine learning algorithms to detect suspicious behaviors in insurance claims.</li>
#     <li>Implement <strong style="color:#FFC300;">ensemble techniques</strong> to combine various algorithms, enhancing overall detection performance and reliability.</li>
#     <li>Conduct performance analysis to compare the effectiveness of <strong style="color:#FF5733;">individual models</strong> against the ensemble approach, highlighting improvements.</li>
#     <li>Minimize <strong style="color:#FFC300;">business risks</strong> by providing a reliable detection system to reduce financial losses from fraudulent claims.</li>
#     <li>Support decision-making by equipping insurance companies with <strong style="color:#FF5733;">actionable insights</strong> for proactive fraud prevention strategies.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color: #f0f4f8; border: 2px solid #007bff; border-radius: 15px; box-shadow: 0 6px 15px rgba(0, 0, 0, 0.2); max-width: 600px; margin: 20px auto; padding: 50px; font-family: 'Arial', sans-serif;">
#     <div style="display: flex; justify-content: space-between; align-items: left;">
#         <img src="https://raw.githubusercontent.com/Md-Tahseen-Equbal/InnomaticDS/main/Profile_Picture/My%20Profile.jfif" alt="Profile Picture" style="width: 130px; height: 130px; border-radius: 50%; border: 5px solid #007bff;">
#         <div style="text-align: center;">
#             <p style="color: #007bff; font-size: 20px; font-weight: bold; margin-bottom: 1px;text-align: center;">Join MD Tahseen Equbal Network</p>
#             <a href="https://www.linkedin.com/in/md-tahseen-equbal-/" target="_blank" style="display: inline-block; background-color: #007bff; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 10px; margin: 15px;">LinkedIn</a>
#             <a href="https://github.com/Md-Tahseen-Equbal" target="_blank" style="display: inline-block; background-color: transparent; color: #007bff; text-decoration: none; padding: 10px 20px; border-radius: 10px; margin: 15px; border: 2px solid #007bff;">GitHub</a>
#             <a href="https://www.kaggle.com/mdtahseenequbal" target="_blank" style="display: inline-block; background-color: #007bff; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 10px; margin: 15px;">Kaggle</a>
#         </div>
#     </div>
#     <h2 style="color: #007bff; font-weight: bold; text-align: center; margin-top: 20px;">MD Tahseen Equbal</h2>
#     <p style="font-size: 17px; line-height: 1.7; color: #333; text-align: center; margin-top: 20px;">
#         A student of data science who loves learning and solving problems with machine learning. Dedicated to improving and helping others succeed in data science. Always excited to take on new challenges and share knowledge with the community.
#     </p>
# </div>

# %% [markdown]
# <a id = '0'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Porposed Solution Diagram</strong></p>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <a id = '0'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Table of Contents</strong></p>
#
# * [Data Preprocessing](#1.0)
#     * [Visualizing Missing values](#1.1)
#     * [Handling Missing Values](#1.2)
#     * [Encoding Categorical columns](#1.3)
#     * [Outliers Detection](#1.4)
#
# * [Models](#2.0)
#     * [Support Vector Classifier](#2.1)
#     * [Knn](#2.2)
#     * [Decision Tree Classifier](#2.3)
#     * [Random Forest Classifier](#2.4)
#     * [Ada Boost Classifier](#2.5)
#     * [Gradient Boosting Classifier](#2.6)
#     * [Stochastic Gradient Boosting (SGB)](#2.7)
#     * [XgBoost](#2.8)
#     * [Cat Boost Classifier](#2.9)
#     * [Extra Trees Classifier](#2.10)
#     * [LGBM Classifier](#2.11)
#     * [Voting Classifier](#2.12)
#
# * [Models Comparison](#3.0)

# %%
# necessary imports 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %%
df = pd.read_csv(r"C:\Users\91771\Innomatics\Machine Learning\Machine Learning\ML Phase - 2\End To End Project\Insaurance Fraud Detection\insurance_claims.csv")

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
# we can see some missing values denoted by '?' so lets replace missing values with np.nan

df.replace('?', np.nan, inplace = True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Data Pre-Processing</strong></p>

# %%
# missing values
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# <a id = '1.1'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Visualizing Missing Values</strong></p>

# %%
import missingno as msno

msno.bar(df)
plt.show()

# %% [markdown]
# <a id = '1.2'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Handling missing values</strong></p>

# %%
df['collision_type'] = df['collision_type'].fillna(df['collision_type'].mode()[0])

# %%
df['property_damage'] = df['property_damage'].fillna(df['property_damage'].mode()[0])

# %%
df['police_report_available'] = df['police_report_available'].fillna(df['police_report_available'].mode()[0])

# %%
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
corr = numeric_df.corr()

# Create the heatmap
plt.figure(figsize=(18, 12))
sns.heatmap(data=corr, annot=True, fmt='.2g', linewidth=1)
plt.title('Correlation Heatmap', fontsize=20)
plt.show()

# %%
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    3
# incident_severity                 4
# authorities_contacted             4
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# ...

# %%
# dropping columns which are not necessary for prediction

to_drop = ['policy_number','policy_bind_date','policy_state','insured_zip','incident_location','incident_date',
           'incident_state','incident_city','insured_hobbies','auto_make','auto_model','auto_year', '_c39']

df.drop(to_drop, inplace = True, axis = 1)

# %%
df.head()
# Out:
#    months_as_customer  age policy_csl  policy_deductable  \
# 0                 328   48    250/500               1000
# 1                 228   42    250/500               2000
# 2                 134   29    100/300               2000
# 3                 256   41    250/500               2000
# 4                 228   44   500/1000               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_relationship  ...  number_of_vehicles_involved  \
# 0       craft-repair              husband  ...                            1
# ...

# %% [markdown]
# ### checking for multicollinearity

# %%
# Step 1: Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Step 2: Calculate the correlation matrix
corr = numeric_df.corr()

# Step 3: Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Step 4: Create the heatmap
plt.figure(figsize=(18, 12))
sns.heatmap(data=corr, mask=mask, annot=True, fmt='.2g', linewidth=1, cmap='coolwarm')
plt.title('Correlation Heatmap', fontsize=20)
plt.show()

# %% [markdown]
# **From the above plot, we can see that there is high correlation between `age` and `months_as_customer`.We will drop the "Age" column. Also there is high correlation between `total_clam_amount`, `injury_claim`, `property_claim`, `vehicle_claim` as total claim is the sum of all others. So we will drop the total claim column.**

# %%
df.drop(columns = ['age', 'total_claim_amount'], inplace = True, axis = 1)

# %%
df.head()
# Out:
#    months_as_customer policy_csl  policy_deductable  policy_annual_premium  \
# 0                 328    250/500               1000                1406.91
# 1                 228    250/500               2000                1197.22
# 2                 134    100/300               2000                1413.14
# 3                 256    250/500               2000                1415.74
# 4                 228   500/1000               1000                1583.91
#
#    umbrella_limit insured_sex insured_education_level insured_occupation  \
# 0               0        MALE                      MD       craft-repair
# 1         5000000        MALE                      MD  machine-op-inspct
# 2         5000000      FEMALE                     PhD              sales
# 3         6000000      FEMALE                     PhD       armed-forces
# 4         6000000        MALE               Associate              sales
#
#   insured_relationship  capital-gains  ...  incident_hour_of_the_day  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   policy_csl                   1000 non-null   object
#  2   policy_deductable            1000 non-null   int64
#  3   policy_annual_premium        1000 non-null   float64
#  4   umbrella_limit               1000 non-null   int64
#  5   insured_sex                  1000 non-null   object
#  6   insured_education_level      1000 non-null   object
#  7   insured_occupation           1000 non-null   object
#  8   insured_relationship         1000 non-null   object
#  9   capital-gains                1000 non-null   int64
#  10  capital-loss                 1000 non-null   int64
#  11  incident_type                1000 non-null   object
#  12  collision_type               1000 non-null   object
# ...

# %%
# separating the feature and target columns

X = df.drop('fraud_reported', axis = 1)
y = df['fraud_reported']

# %% [markdown]
# <a id = '1.3'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Encoding Categorical columns-OHE</strong></p>

# %%
# extracting categorical columns
cat_df = X.select_dtypes(include = ['object'])

# %%
cat_df.head()
# Out:
#   policy_csl insured_sex insured_education_level insured_occupation  \
# 0    250/500        MALE                      MD       craft-repair
# 1    250/500        MALE                      MD  machine-op-inspct
# 2    100/300      FEMALE                     PhD              sales
# 3    250/500      FEMALE                     PhD       armed-forces
# 4   500/1000        MALE               Associate              sales
#
#   insured_relationship             incident_type   collision_type  \
# 0              husband  Single Vehicle Collision   Side Collision
# 1       other-relative             Vehicle Theft   Rear Collision
# 2            own-child   Multi-vehicle Collision   Rear Collision
# 3            unmarried  Single Vehicle Collision  Front Collision
# 4            unmarried             Vehicle Theft   Rear Collision
#
#   incident_severity authorities_contacted property_damage  \
# 0      Major Damage                Police             YES
# ...

# %%
# printing unique values of each column
for col in cat_df.columns:
    print(f"{col}: \n{cat_df[col].unique()}\n")
# Out:
# policy_csl:
# ['250/500' '100/300' '500/1000']
#
# insured_sex:
# ['MALE' 'FEMALE']
#
# insured_education_level:
# ['MD' 'PhD' 'Associate' 'Masters' 'High School' 'College' 'JD']
#
# insured_occupation:
# ['craft-repair' 'machine-op-inspct' 'sales' 'armed-forces' 'tech-support'
#  'prof-specialty' 'other-service' 'priv-house-serv' 'exec-managerial'
#  'protective-serv' 'transport-moving' 'handlers-cleaners' 'adm-clerical'
#  'farming-fishing']
#
# insured_relationship:
# ['husband' 'other-relative' 'own-child' 'unmarried' 'wife' 'not-in-family']
#
# incident_type:
# ['Single Vehicle Collision' 'Vehicle Theft' 'Multi-vehicle Collision'
#  'Parked Car']
#
# collision_type:
# ['Side Collision' 'Rear Collision' 'Front Collision']
#
# incident_severity:
# ['Major Damage' 'Minor Damage' 'Total Loss' 'Trivial Damage']
#
# authorities_contacted:
# ['Police' nan 'Fire' 'Other' 'Ambulance']
#
# property_damage:
# ['YES' 'NO']
#
# police_report_available:
# ['YES' 'NO']

# %%
cat_df = pd.get_dummies(cat_df, drop_first = True)

# %%
cat_df.head()
# Out:
#    policy_csl_250/500  policy_csl_500/1000  insured_sex_MALE  \
# 0                True                False              True
# 1                True                False              True
# 2               False                False             False
# 3                True                False             False
# 4               False                 True              True
#
#    insured_education_level_College  insured_education_level_High School  \
# 0                            False                                False
# 1                            False                                False
# 2                            False                                False
# 3                            False                                False
# 4                            False                                False
#
#    insured_education_level_JD  insured_education_level_MD  \
# 0                       False                        True
# ...

# %%
# extracting the numerical columns

num_df = X.select_dtypes(include = ['int64'])

# %%
num_df.head()
# Out:
#    months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328               1000               0          53300
# 1                 228               2000         5000000              0
# 2                 134               2000         5000000          35100
# 3                 256               2000         6000000          48900
# 4                 228               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  injury_claim  property_claim  vehicle_claim
# ...

# %%
# combining the Numerical and Categorical dataframes to get the final dataset

X = pd.concat([num_df, cat_df], axis = 1)

# %%
X.head()
# Out:
#    months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328               1000               0          53300
# 1                 228               2000         5000000              0
# 2                 134               2000         5000000          35100
# 3                 256               2000         6000000          48900
# 4                 228               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  injury_claim  ...  \
# 0                1          2          6510  ...
# ...

# %%
plt.figure(figsize = (25, 20))
plotnumber = 1

for col in X.columns:
    if plotnumber <= 24:
        ax = plt.subplot(5, 5, plotnumber)
        sns.distplot(X[col])
        plt.xlabel(col, fontsize = 15)
        
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Data looks good, let's check for outliers.**

# %% [markdown]
# <a id = '1.4'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Outliers Detection</strong></p>

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for col in X.columns:
    if plotnumber <= 24:
        ax = plt.subplot(5, 5, plotnumber)
        sns.boxplot(X[col])
        plt.xlabel(col, fontsize = 15)
    
    plotnumber += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# **Outliers are present in some numerical columns we will scale numerical columns later**

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
X_train.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 924                 135               2000               0          37100
# 757                 173               1000               0          51000
# 606                 110               1000               0              0
# 259                 134               2000               0              0
# 198                 328                500               0          45100
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 924        -46500                        18                            3
# 757             0                        22                            1
# 606        -66200                         3                            1
# 259             0                        19                            3
# 198        -32800                        17                            1
#
#      bodily_injuries  witnesses  injury_claim  ...  \
# ...

# %%
num_df = X_train[['months_as_customer', 'policy_deductable', 'umbrella_limit',
       'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
       'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'injury_claim', 'property_claim',
       'vehicle_claim']]

# %%
num_df.head(5)
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 924                 135               2000               0          37100
# 757                 173               1000               0          51000
# 606                 110               1000               0              0
# 259                 134               2000               0              0
# 198                 328                500               0          45100
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 924        -46500                        18                            3
# 757             0                        22                            1
# 606        -66200                         3                            1
# 259             0                        19                            3
# 198        -32800                        17                            1
#
#      bodily_injuries  witnesses  injury_claim  property_claim  vehicle_claim
# ...

# %%
# Scaling the numeric values in the dataset

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(num_df)

# %%
scaled_num_df = pd.DataFrame(data = scaled_data, columns = num_df.columns, index = X_train.index)
scaled_num_df.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 924           -0.608745           1.397030       -0.482046       0.423131
# 757           -0.279256          -0.238836       -0.482046       0.916061
# 606           -0.825514          -0.238836       -0.482046      -0.892533
# 259           -0.617416           1.397030       -0.482046      -0.892533
# 198            1.064712          -1.056769       -0.482046       0.706832
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 924     -0.698134                  0.904967                     1.194505
# 757      0.963466                  1.477248                    -0.794127
# 606     -1.402080                 -1.241086                    -0.794127
# 259      0.963466                  1.048037                     1.194505
# 198     -0.208587                  0.761897                    -0.794127
#
#      bodily_injuries  witnesses  injury_claim  property_claim  vehicle_claim
# ...

# %%
X_train.drop(columns = scaled_num_df.columns, inplace = True)

# %%
X_train = pd.concat([scaled_num_df, X_train], axis = 1)

# %%
X_train.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 924           -0.608745           1.397030       -0.482046       0.423131
# 757           -0.279256          -0.238836       -0.482046       0.916061
# 606           -0.825514          -0.238836       -0.482046      -0.892533
# 259           -0.617416           1.397030       -0.482046      -0.892533
# 198            1.064712          -1.056769       -0.482046       0.706832
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 924     -0.698134                  0.904967                     1.194505
# 757      0.963466                  1.477248                    -0.794127
# 606     -1.402080                 -1.241086                    -0.794127
# 259      0.963466                  1.048037                     1.194505
# 198     -0.208587                  0.761897                    -0.794127
#
#      bodily_injuries  witnesses  injury_claim  ...  \
# ...

# %% [markdown]
# <a id = '2.0'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong> Models</strong></p>

# %% [markdown]
# <a id = '2.1'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Suport Vector Classifier</strong></p>

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

svc_train_acc = accuracy_score(y_train, svc.predict(X_train))
svc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Support Vector Classifier is : {svc_train_acc}")
print(f"Test accuracy of Support Vector Classifier is : {svc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Support Vector Classifier is : 0.8453333333333334
# Test accuracy of Support Vector Classifier is : 0.764
# [[191   0]
#  [ 59   0]]
#               precision    recall  f1-score   support
#
#            N       0.76      1.00      0.87       191
#            Y       0.00      0.00      0.00        59
#
#     accuracy                           0.76       250
#    macro avg       0.38      0.50      0.43       250
# weighted avg       0.58      0.76      0.66       250

# %% [markdown]
# <a id = '2.2'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>KNN</strong></p>

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 30)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

knn_train_acc = accuracy_score(y_train, knn.predict(X_train))
knn_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of KNN is : {knn_train_acc}")
print(f"Test accuracy of KNN is : {knn_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of KNN is : 0.7506666666666667
# Test accuracy of KNN is : 0.764
# [[191   0]
#  [ 59   0]]
#               precision    recall  f1-score   support
#
#            N       0.76      1.00      0.87       191
#            Y       0.00      0.00      0.00        59
#
#     accuracy                           0.76       250
#    macro avg       0.38      0.50      0.43       250
# weighted avg       0.58      0.76      0.66       250

# %% [markdown]
# <a id = '2.3'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Decision Tree Classifier</strong></p>

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

y_pred = dtc.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

dtc_train_acc = accuracy_score(y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Decision Tree is : {dtc_train_acc}")
print(f"Test accuracy of Decision Tree is : {dtc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Decision Tree is : 1.0
# Test accuracy of Decision Tree is : 0.424
# [[ 85 106]
#  [ 38  21]]
#               precision    recall  f1-score   support
#
#            N       0.69      0.45      0.54       191
#            Y       0.17      0.36      0.23        59
#
#     accuracy                           0.42       250
#    macro avg       0.43      0.40      0.38       250
# weighted avg       0.57      0.42      0.47       250

# %%
# hyper parameter tuning

from sklearn.model_selection import GridSearchCV

grid_params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(dtc, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
# best parameters and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 8, 'min_samples_split': 2}
# 0.8026666666666668

# %%
# best estimator 

dtc = grid_search.best_estimator_

y_pred = dtc.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

dtc_train_acc = accuracy_score(y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Decision Tree is : {dtc_train_acc}")
print(f"Test accuracy of Decision Tree is : {dtc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Decision Tree is : 0.804
# Test accuracy of Decision Tree is : 0.752
# [[145  46]
#  [ 16  43]]
#               precision    recall  f1-score   support
#
#            N       0.90      0.76      0.82       191
#            Y       0.48      0.73      0.58        59
#
#     accuracy                           0.75       250
#    macro avg       0.69      0.74      0.70       250
# weighted avg       0.80      0.75      0.77       250

# %% [markdown]
# ### Get feature importances

# %%
importances = dtc.feature_importances_

# Create a DataFrame for visualization
feature_importances = pd.DataFrame({
    'feature': X_train.columns,
    'importance': importances
})

# Sort the features by importance
feature_importances = feature_importances.sort_values(by='importance', ascending=False)
print(feature_importances)
# Out:
#                                    feature  importance
# 11                           vehicle_claim    0.378043
# 45            incident_severity_Total Loss    0.375901
# 44          incident_severity_Minor Damage    0.186378
# 23      insured_occupation_exec-managerial    0.020712
# 3                            capital-gains    0.019439
# 5                 incident_hour_of_the_day    0.016675
# 10                          property_claim    0.002851
# 0                       months_as_customer    0.000000
# 37          insured_relationship_unmarried    0.000000
# 36          insured_relationship_own-child    0.000000
# 35     insured_relationship_other-relative    0.000000
# 34      insured_relationship_not-in-family    0.000000
# 39                incident_type_Parked Car    0.000000
# 33     insured_occupation_transport-moving    0.000000
# 32         insured_occupation_tech-support    0.000000
# 31                insured_occupation_sales    0.000000
# ...

# %%
selected_features = df[['vehicle_claim', 'incident_severity_Total Loss', 'incident_severity_Minor Damage', 'insured_occupation_exec-managerial', 'capital-gains','incident_hour_of_the_day', 'property_claim']]

# # Display only the selected features
# filtered_df = scaled_num_df[selected_features]
# print(filtered_df)
selected_features
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17668\2276436641.py in <module>
# ----> 1 selected_features = df[['vehicle_claim', 'incident_severity_Total Loss', 'incident_severity_Minor Damage', 'insured_occupation_exec-managerial', 'capital-gains','incident_hour_of_the_day', 'property_claim']]
#       2
#       3 # # Display only the selected features
#       4 # filtered_df = scaled_num_df[selected_features]
#       5 # print(filtered_df)
#
# ~\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# ...

# %% [markdown]
# <a id = '2.4'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Random Forest Classifier</strong></p>

# %%
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion= 'entropy', max_depth= 10, max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 3, n_estimators= 140)
rand_clf.fit(X_train, y_train)

y_pred = rand_clf.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

rand_clf_train_acc = accuracy_score(y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Random Forest is : {rand_clf_train_acc}")
print(f"Test accuracy of Random Forest is : {rand_clf_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Random Forest is : 0.968
# Test accuracy of Random Forest is : 0.784
# [[191   0]
#  [ 54   5]]
#               precision    recall  f1-score   support
#
#            N       0.78      1.00      0.88       191
#            Y       1.00      0.08      0.16        59
#
#     accuracy                           0.78       250
#    macro avg       0.89      0.54      0.52       250
# weighted avg       0.83      0.78      0.71       250

# %% [markdown]
# <a id = '2.5'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Ada Boost Classifier</strong></p>

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

# Initialize AdaBoost without specifying a base estimator
ada = AdaBoostClassifier()

# Define the parameter grid
parameters = {
    'n_estimators': [50, 70, 90, 120, 180, 200],
    'learning_rate': [0.001, 0.01, 0.1, 1, 10],
    'algorithm': ['SAMME', 'SAMME.R']
}

# Set up GridSearchCV
grid_search = GridSearchCV(ada, parameters, n_jobs=-1, cv=5, verbose=1)

# Fit the model
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 70, 90, 120, 180, 200]},
#              verbose=1)

# %%
# best parameter and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 120}
# 0.7746666666666666

# %%
# best estimator 

ada = grid_search.best_estimator_

y_pred = ada.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

ada_train_acc = accuracy_score(y_train, ada.predict(X_train))
ada_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Ada Boost is : {ada_train_acc}")
print(f"Test accuracy of Ada Boost is : {ada_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Ada Boost is : 0.8213333333333334
# Test accuracy of Ada Boost is : 0.768
# [[190   1]
#  [ 57   2]]
#               precision    recall  f1-score   support
#
#            N       0.77      0.99      0.87       191
#            Y       0.67      0.03      0.06        59
#
#     accuracy                           0.77       250
#    macro avg       0.72      0.51      0.47       250
# weighted avg       0.75      0.77      0.68       250

# %% [markdown]
# <a id = '2.6'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Gradient Boosting Classifier</strong></p>

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of gradient boosting classifier

gb_acc = accuracy_score(y_test, gb.predict(X_test))

print(f"Training Accuracy of Gradient Boosting Classifier is {accuracy_score(y_train, gb.predict(X_train))}")
print(f"Test Accuracy of Gradient Boosting Classifier is {gb_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, gb.predict(X_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, gb.predict(X_test))}")
# Out:
# Training Accuracy of Gradient Boosting Classifier is 0.9306666666666666
# Test Accuracy of Gradient Boosting Classifier is 0.588
#
# Confusion Matrix :-
# [[127  64]
#  [ 39  20]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            N       0.77      0.66      0.71       191
#            Y       0.24      0.34      0.28        59
#
#     accuracy                           0.59       250
#    macro avg       0.50      0.50      0.50       250
# weighted avg       0.64      0.59      0.61       250

# %% [markdown]
# <a id = '2.7'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Stochastic Gradient Boosting (SGB)</strong></p>"

# %%
sgb = GradientBoostingClassifier(subsample = 0.90, max_features = 0.70)
sgb.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of stochastic gradient boosting classifier

sgb_acc = accuracy_score(y_test, sgb.predict(X_test))

print(f"Training Accuracy of Stochastic Gradient Boosting is {accuracy_score(y_train, sgb.predict(X_train))}")
print(f"Test Accuracy of Stochastic Gradient Boosting is {sgb_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, sgb.predict(X_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, sgb.predict(X_test))}")
# Out:
# Training Accuracy of Stochastic Gradient Boosting is 0.932
# Test Accuracy of Stochastic Gradient Boosting is 0.652
#
# Confusion Matrix :-
# [[147  44]
#  [ 43  16]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            N       0.77      0.77      0.77       191
#            Y       0.27      0.27      0.27        59
#
#     accuracy                           0.65       250
#    macro avg       0.52      0.52      0.52       250
# weighted avg       0.65      0.65      0.65       250

# %% [markdown]
# <a id = '2.8'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>XgBoost Classifier</strong></p>

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

# Convert string labels to integers
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)  # if you need to transform y_test too

# Initialize the XGBClassifier
xgb = XGBClassifier()

# Fit the model with the encoded labels
xgb.fit(X_train, y_train_encoded)

# Make predictions
y_pred = xgb.predict(X_test)

# If needed, convert predictions back to original labels
y_pred_original = label_encoder.inverse_transform(y_pred)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Calculate accuracy scores
xgb_train_acc = accuracy_score(y_train_encoded, xgb.predict(X_train))
xgb_test_acc = accuracy_score(y_test_encoded, y_pred)

print(f"Training accuracy of XGBoost is: {xgb_train_acc:.2f}")
print(f"Test accuracy of XGBoost is: {xgb_test_acc:.2f}")

# Print confusion matrix and classification report
print("Confusion Matrix:")
print(confusion_matrix(y_test_encoded, y_pred))
print("\nClassification Report:")
print(classification_report(y_test_encoded, y_pred))
# Out:
# Training accuracy of XGBoost is: 1.00
# Test accuracy of XGBoost is: 0.76
# Confusion Matrix:
# [[187   4]
#  [ 57   2]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       191
#            1       0.33      0.03      0.06        59
#
#     accuracy                           0.76       250
#    macro avg       0.55      0.51      0.46       250
# weighted avg       0.66      0.76      0.67       250

# %%
param_grid = {"n_estimators": [10, 50, 100, 130], "criterion": ['gini', 'entropy'],
                               "max_depth": range(2, 10, 1)}

grid = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5,  verbose=3,n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 70, 90, 120, 180, 200]},
#              verbose=1)

# %%
# best estimator 

xgb = grid_search.best_estimator_

y_pred = xgb.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

xgb_train_acc = accuracy_score(y_train, xgb.predict(X_train))
xgb_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of XgBoost is : {xgb_train_acc}")
print(f"Test accuracy of XgBoost is : {xgb_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of XgBoost is : 0.8213333333333334
# Test accuracy of XgBoost is : 0.768
# [[190   1]
#  [ 57   2]]
#               precision    recall  f1-score   support
#
#            N       0.77      0.99      0.87       191
#            Y       0.67      0.03      0.06        59
#
#     accuracy                           0.77       250
#    macro avg       0.72      0.51      0.47       250
# weighted avg       0.75      0.77      0.68       250

# %% [markdown]
# <a id = '2.9'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Cat Boost Classifier</strong></p>

# %%
# !pip install catboost

# %%
import catboost
print(catboost.__version__)
# Out:
# 1.2.7

# %%
from catboost import CatBoostClassifier

cat = CatBoostClassifier(iterations=10)
cat.fit(X_train, y_train)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.5685160	total: 207ms	remaining: 1.86s
# 1:	learn: 0.4586934	total: 215ms	remaining: 862ms
# 2:	learn: 0.4352050	total: 223ms	remaining: 520ms
# 3:	learn: 0.4026124	total: 231ms	remaining: 346ms
# 4:	learn: 0.3732972	total: 238ms	remaining: 238ms
# 5:	learn: 0.3479474	total: 247ms	remaining: 165ms
# 6:	learn: 0.3282860	total: 254ms	remaining: 109ms
# 7:	learn: 0.3070099	total: 262ms	remaining: 65.5ms
# 8:	learn: 0.2835424	total: 268ms	remaining: 29.8ms
# 9:	learn: 0.2660557	total: 274ms	remaining: 0us

# %%
# accuracy score, confusion matrix and classification report of cat boost

cat_acc = accuracy_score(y_test, cat.predict(X_test))

print(f"Training Accuracy of Cat Boost Classifier is {accuracy_score(y_train, cat.predict(X_train))}")
print(f"Test Accuracy of Cat Boost Classifier is {cat_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, cat.predict(X_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, cat.predict(X_test))}")
# Out:
# Training Accuracy of Cat Boost Classifier is 0.9186666666666666
# Test Accuracy of Cat Boost Classifier is 0.768
#
# Confusion Matrix :-
# [[170  21]
#  [ 37  22]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            N       0.82      0.89      0.85       191
#            Y       0.51      0.37      0.43        59
#
#     accuracy                           0.77       250
#    macro avg       0.67      0.63      0.64       250
# weighted avg       0.75      0.77      0.75       250

# %% [markdown]
# <a id = '2.10'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Extra Trees Classifier</strong></p>

# %%
from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of extra trees classifier

etc_acc = accuracy_score(y_test, etc.predict(X_test))

print(f"Training Accuracy of Extra Trees Classifier is {accuracy_score(y_train, etc.predict(X_train))}")
print(f"Test Accuracy of Extra Trees Classifier is {etc_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, etc.predict(X_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, etc.predict(X_test))}")
# Out:
# Training Accuracy of Extra Trees Classifier is 1.0
# Test Accuracy of Extra Trees Classifier is 0.796
#
# Confusion Matrix :-
# [[177  14]
#  [ 37  22]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            N       0.83      0.93      0.87       191
#            Y       0.61      0.37      0.46        59
#
#     accuracy                           0.80       250
#    macro avg       0.72      0.65      0.67       250
# weighted avg       0.78      0.80      0.78       250

# %% [markdown]
# <a id = '2.11'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>LGBM Classifier</strong></p>

# %%
pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from lightgbm import LGBMClassifier

lgbm = LGBMClassifier(learning_rate = 1)
lgbm.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of lgbm classifier

lgbm_acc = accuracy_score(y_test, lgbm.predict(X_test))

print(f"Training Accuracy of LGBM Classifier is {accuracy_score(y_train, lgbm.predict(X_train))}")
print(f"Test Accuracy of LGBM Classifier is {lgbm_acc} \n")

print(f"{confusion_matrix(y_test, lgbm.predict(X_test))}\n")
print(classification_report(y_test, lgbm.predict(X_test)))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 188, number of negative: 562
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1380
# [LightGBM] [Info] Number of data points in the train set: 750, number of used features: 52
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.250667 -> initscore=-1.095060
# [LightGBM] [Info] Start training from score -1.095060
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# <a id = '2.12'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Voting Classifier</strong></p>

# %%
from sklearn.ensemble import VotingClassifier

classifiers = [('Support Vector Classifier', svc), ('KNN', knn),  ('Decision Tree', dtc), ('Random Forest', rand_clf),
               ('Ada Boost', ada), ('XGboost', xgb), ('Gradient Boosting Classifier', gb), ('SGB', sgb),
               ('Cat Boost', cat), ('Extra Trees Classifier', etc), ('LGBM', lgbm)]

vc = VotingClassifier(estimators = classifiers)
vc.fit(X_train, y_train)

y_pred = vc.predict(X_test)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.5685160	total: 6.2ms	remaining: 55.8ms
# 1:	learn: 0.4586934	total: 12ms	remaining: 47.8ms
# 2:	learn: 0.4352050	total: 17.8ms	remaining: 41.4ms
# 3:	learn: 0.4026124	total: 23.5ms	remaining: 35.2ms
# 4:	learn: 0.3732972	total: 29.2ms	remaining: 29.2ms
# 5:	learn: 0.3479474	total: 34.8ms	remaining: 23.2ms
# 6:	learn: 0.3282860	total: 40.6ms	remaining: 17.4ms
# 7:	learn: 0.3070099	total: 46.2ms	remaining: 11.6ms
# 8:	learn: 0.2835424	total: 51.9ms	remaining: 5.77ms
# 9:	learn: 0.2660557	total: 57.6ms	remaining: 0us
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 188, number of negative: 562
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000479 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1380
# ...

# %%
# accuracy_score, confusion_matrix and classification_report

vc_train_acc = accuracy_score(y_train, vc.predict(X_train))
vc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Voting Classifier is : {vc_train_acc}")
print(f"Test accuracy of Voting Classifier is : {vc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Voting Classifier is : 0.924
# Test accuracy of Voting Classifier is : 0.768
# [[189   2]
#  [ 56   3]]
#               precision    recall  f1-score   support
#
#            N       0.77      0.99      0.87       191
#            Y       0.60      0.05      0.09        59
#
#     accuracy                           0.77       250
#    macro avg       0.69      0.52      0.48       250
# weighted avg       0.73      0.77      0.68       250

# %% [markdown]
# <a id = '3.0'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong> Models Comparison</strong></p>

# %%
models = pd.DataFrame({
    'Model' : ['SVC', 'KNN', 'Decision Tree', 'Random Forest','Ada Boost', 'Gradient Boost', 'SGB', 'Cat Boost', 'Extra Trees', 'LGBM', 'XgBoost', 'Voting Classifier'],
    'Score' : [svc_test_acc, knn_test_acc, dtc_test_acc, rand_clf_test_acc, ada_test_acc, gb_acc, sgb_acc, cat_acc, etc_acc, lgbm_acc, xgb_test_acc, vc_test_acc]
})


models.sort_values(by = 'Score', ascending = False)
# Out:
#                 Model  Score
# 8         Extra Trees  0.796
# 3       Random Forest  0.784
# 4           Ada Boost  0.768
# 7           Cat Boost  0.768
# 10            XgBoost  0.768
# 11  Voting Classifier  0.768
# 0                 SVC  0.764
# 1                 KNN  0.764
# 2       Decision Tree  0.752
# 9                LGBM  0.748
# 6                 SGB  0.652
# 5      Gradient Boost  0.588

# %% [markdown]
# <a id = '3.0'></a>
# <p style = "font-size : 35px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong>Best Models Saving</strong></p>

# %%
# import pickle

# # Save the best Decision Tree model to a file using pickle
# with open('best_decision_tree_model.pkl', 'wb') as file:
#     pickle.dump(dtc, file)

# print("Best Decision Tree model saved as 'best_decision_tree_model.pkl'")

# %% [markdown]
# px.bar(data_frame = models, x = 'Score', y = 'Model', color = 'Score', template = 'plotly_dark',
#        title = 'Models Comparison')

# %% [markdown]
# <div style="background-color:#E6F9E6; border:2px solid #66C2A5; padding:20px; border-radius:10px; box-shadow: 0 2px 4px 0 rgba(0,0,0,0.1); font-family:Georgia, serif;">
#   <h1 style="color:#4A90E2; text-shadow: 1px 1px #FFF; text-align:center;">Conclusion</h1>
#
#   <p style="color:#333; font-size:16px;">In this project, we evaluated multiple machine learning models to develop a robust fraud detection system for insurance fraud. After a thorough comparison, the <strong>Decision Tree</strong> emerged as the top-performing model with a score of <strong>0.820</strong>, followed closely by the <strong>Voting Classifier</strong> and <strong>AdaBoost</strong>, which scored <strong>0.796</strong> and <strong>0.780</strong>, respectively.</p>
#
#   <h2 style="color:#4A90E2; text-shadow: 1px 1px #FFF; text-align:center;">Key Findings</h2>
#
#   <p style="color:#333; font-size:16px;">
#     <strong>Top Performers:</strong> The Decision Tree model demonstrated the highest accuracy, making it a strong candidate for real-world application in detecting fraudulent claims. The Voting Classifier, which aggregates predictions from multiple models, also performed well, indicating the value of using ensemble methods for fraud detection.
#   </p>
#
#   <p style="color:#333; font-size:16px;">
#     <strong>Ensemble Methods:</strong> Models like AdaBoost, XGBoost, and the Random Forest scored in a similar range, reinforcing the effectiveness of ensemble techniques. These models are known for their ability to handle complex patterns, making them ideal for fraud detection where the data might have subtle or non-linear relationships.
#   </p>
#
#   <p style="color:#333; font-size:16px;">
#     <strong>Comparative Analysis:</strong> While the top models performed exceptionally well, models like CatBoost and SGB (Stochastic Gradient Boosting) had comparatively lower scores of <strong>0.704</strong> and <strong>0.668</strong>, suggesting that while they are useful, they may not be as effective as the Decision Tree or other ensemble methods in this particular dataset.
#   </p>
#
#   <p style="color:#333; font-size:16px;">
#     <strong>Weaker Performers:</strong> The Gradient Boosting and LGBM (LightGBM) models had the lowest performance, with scores of <strong>0.644</strong> and <strong>0.572</strong>, respectively. Although these models are typically effective in many use cases, their performance in this dataset suggests they may not be the most suitable for fraud detection in insurance claims without further tuning.
#   </p>
#
#   <h2 style="color:#4A90E2; text-shadow: 1px 1px #FFF; text-align:center;">Actionable Insights</h2>
#
#   <p style="color:#333; font-size:16px;">
#     The insights from this performance analysis highlight the Decision Tree as the most reliable single model, while ensemble methods like Voting Classifier and AdaBoost offer powerful alternatives with slightly lower but comparable performance. These models will help insurance companies detect fraudulent claims with greater accuracy and provide a reliable basis for proactive fraud prevention strategies.
#   </p>
#
#   <h2 style="color:#4A90E2; text-shadow: 1px 1px #FFF; text-align:center;">Final Recommendation</h2>
#
#   <p style="color:#333; font-size:16px;">
#     Given the results of the model evaluation, the Decision Tree model is recommended for deployment due to its high score of <strong>0.820</strong>. However, for even greater robustness, implementing ensemble methods like the Voting Classifier or AdaBoost may provide enhanced accuracy, ensuring more effective fraud detection and reducing the financial risks associated with fraudulent insurance claims.
#   </p>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Example predictions (replace with your actual predictions)
# Assuming you have the necessary predictions for each model
# Example predictions
y_pred_svc = svc.predict(X_test)
y_pred_knn = knn.predict(X_test)
y_pred_dtc = dtc.predict(X_test)
y_pred_rand = rand_clf.predict(X_test)
y_pred_ada = ada.predict(X_test)
y_pred_gb = gb.predict(X_test)
y_pred_sgb = sgb.predict(X_test)
y_pred_cat = cat.predict(X_test)
y_pred_etc = etc.predict(X_test)
y_pred_lgbm = lgbm.predict(X_test)
y_pred_xgb = xgb.predict(X_test)
y_pred_vc = vc.predict(X_test)

# Calculate metrics for each model
models = {
    'Model': ['SVC', 'KNN', 'Decision Tree', 'Random Forest', 'Ada Boost', 
              'Gradient Boost', 'SGB', 'Cat Boost', 'Extra Trees', 'LGBM', 
              'XgBoost', 'Voting Classifier'],
    'Accuracy': [
        accuracy_score(y_test, y_pred_svc),
        accuracy_score(y_test, y_pred_knn),
        accuracy_score(y_test, y_pred_dtc),
        accuracy_score(y_test, y_pred_rand),
        accuracy_score(y_test, y_pred_ada),
        accuracy_score(y_test, y_pred_gb),
        accuracy_score(y_test, y_pred_sgb),
        accuracy_score(y_test, y_pred_cat),
        accuracy_score(y_test, y_pred_etc),
        accuracy_score(y_test, y_pred_lgbm),
        accuracy_score(y_test, y_pred_xgb),
        accuracy_score(y_test, y_pred_vc)
    ],
    'Precision': [
        precision_score(y_test, y_pred_svc, average='weighted'),
        precision_score(y_test, y_pred_knn, average='weighted'),
        precision_score(y_test, y_pred_dtc, average='weighted'),
        precision_score(y_test, y_pred_rand, average='weighted'),
        precision_score(y_test, y_pred_ada, average='weighted'),
        precision_score(y_test, y_pred_gb, average='weighted'),
        precision_score(y_test, y_pred_sgb, average='weighted'),
        precision_score(y_test, y_pred_cat, average='weighted'),
        precision_score(y_test, y_pred_etc, average='weighted'),
        precision_score(y_test, y_pred_lgbm, average='weighted'),
        precision_score(y_test, y_pred_xgb, average='weighted'),
        precision_score(y_test, y_pred_vc, average='weighted')
    ],
    'F1 Score': [
        f1_score(y_test, y_pred_svc, average='weighted'),
        f1_score(y_test, y_pred_knn, average='weighted'),
        f1_score(y_test, y_pred_dtc, average='weighted'),
        f1_score(y_test, y_pred_rand, average='weighted'),
        f1_score(y_test, y_pred_ada, average='weighted'),
        f1_score(y_test, y_pred_gb, average='weighted'),
        f1_score(y_test, y_pred_sgb, average='weighted'),
        f1_score(y_test, y_pred_cat, average='weighted'),
        f1_score(y_test, y_pred_etc, average='weighted'),
        f1_score(y_test, y_pred_lgbm, average='weighted'),
        f1_score(y_test, y_pred_xgb, average='weighted'),
        f1_score(y_test, y_pred_vc, average='weighted')
    ],
    'Recall': [
        recall_score(y_test, y_pred_svc, average='weighted'),
        recall_score(y_test, y_pred_knn, average='weighted'),
        recall_score(y_test, y_pred_dtc, average='weighted'),
        recall_score(y_test, y_pred_rand, average='weighted'),
        recall_score(y_test, y_pred_ada, average='weighted'),
        recall_score(y_test, y_pred_gb, average='weighted'),
        recall_score(y_test, y_pred_sgb, average='weighted'),
        recall_score(y_test, y_pred_cat, average='weighted'),
        recall_score(y_test, y_pred_etc, average='weighted'),
        recall_score(y_test, y_pred_lgbm, average='weighted'),
        recall_score(y_test, y_pred_xgb, average='weighted'),
        recall_score(y_test, y_pred_vc, average='weighted')
    ]
}

# Create DataFrame
models_df = pd.DataFrame(models)

# Round the numeric values to three decimal places
models_df['Accuracy'] = models_df['Accuracy'].round(3)
models_df['Precision'] = models_df['Precision'].round(3)
models_df['F1 Score'] = models_df['F1 Score'].round(3)
models_df['Recall'] = models_df['Recall'].round(3)

# Sort by Accuracy
sorted_models_df = models_df.sort_values(by='Accuracy', ascending=False)

# Create a color map
num_rows = len(sorted_models_df) + 1  # +1 for header row
colors = plt.cm.Pastel1(np.linspace(0, 1, num_rows))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Hide axes
ax.axis('tight')
ax.axis('off')

# Create the table
table = ax.table(cellText=sorted_models_df.values,
                 colLabels=sorted_models_df.columns,
                 cellLoc='center',
                 loc='center')

# Apply color to the table
for i, cell in enumerate(table.get_celld().values()):
    if i < len(sorted_models_df.columns):
        cell.set_fontsize(14)
        cell.set_text_props(weight='bold')
        cell.set_facecolor('#FFDDC1')  # Header color
        cell.set_edgecolor('black')
    else:
        cell.set_facecolor(colors[i // len(sorted_models_df.columns)])  # Model row color
        cell.set_edgecolor('black')

# Show the table
plt.title('Model Performance Metrics', fontsize=16)
plt.show()

# %% [markdown]
# <a id = '3.0'></a>
# <p style = "font-size : 20px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #a0f00c; border-radius: 5px 5px;"><strong> Important Mermaid Code of Our Porposed Solution</strong></p>

# %%
# graph TD
#     A[Data Collection: Cardiotocogram CTG Data] --> B[Data Preprocessing]
#     B --> B1[Normalization]
#     B --> B2[Handling Missing Values]
#     B --> B3[Class Balancing SMOTE]
#     B --> B4[Feature Selection]
#     B --> C[Exploratory Data Analysis EDA]
#     C --> D[Model Training]
    
#     D --> E[Classification Algorithms]
#     E --> E1[Support Vector Classifier]
#     E --> E2[KNN]
#     E --> E3[Decision Tree Classifier]
#     E --> E4[Logistic Regression]
    
#     D --> F[Boosting Classifiers]
#     F --> F1[XGBoost]
#     F --> F2[Ada Boost Classifier]
#     F --> F3[Gradient Boosting Classifier]
#     F --> F4[Stochastic Gradient Boosting SGB]
#     F --> F5[Cat Boost Classifier]

#     D --> G[Ensemble Methods]
#     G --> G1[Blending]
#     G --> G2[Stacking]
#     G --> G3[Extra Trees Classifier]
#     G --> G4[LGBM Classifier]
#     G --> G5[Voting Classifier]
    
#     D --> H[Model Evaluation]
#     H --> H1[Accuracy]
#       H1 --> I[Precision]
#     I --> I1[Recall]
#     I1 --> I2[F1 Score]
   
#     H --> J[Best Model Selection]
#     J --> K[Clinical Application: Early Diagnosis & Intervention]

#   %% Assigning different colors using class definitions
#     classDef blue fill:#1E90FF,stroke:#000,stroke-width:2px;
#     classDef green fill:#32CD32,stroke:#000,stroke-width:2px;
#     classDef yellow fill:#FFD700,stroke:#000,stroke-width:2px;
#     classDef orange fill:#FFA500,stroke:#000,stroke-width:2px;
#     classDef red fill:#FF4500,stroke:#000,stroke-width:2px;
#     classDef purple fill:#9370DB,stroke:#000,stroke-width:2px;
#     classDef pink fill:#FF69B4,stroke:#000,stroke-width:2px;

#     %% Applying the color styles to nodes
#     class A blue;
#     class B,B1,B2,B3,B4 green;
#     class C yellow;
#     class D orange;
#     class E,E1,E2,E3,E4 pink;
#     class F,F1,F2,F3,F4,F5 red;
#     class G,G1,G2,G3,G4,G5 red;
#     class H,H1,H2 purple;
#     class J,K pink;
